# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# %%
keywords = ['#chatgpt security', '#chatgpt cybersecurity','#chatgpt hackers','#chatgpt cyberthreat']
limit = 200000

tweets_data = []

for keyword in keywords:
    search_query = f'{keyword} until:2022-12-30 since:2022-11-29'
    tweets = list(sntwitter.TwitterSearchScraper(search_query).get_items())[:limit]
    
    
    for tweet in tweets:
        tweet_data = {
            'id':tweet.id,
            'date':tweet.date,
            'content':tweet.rawContent,
            'username':tweet.user.username,
            'verified':tweet.user.verified, 
            'location':tweet.user.location,
            'followerscount':tweet.user.followersCount,
            'language':tweet.lang,
            'mentions':tweet.mentionedUsers,
            'hashtags':tweet.hashtags
        }
        tweets_data.append(tweet_data)
df = pd.DataFrame(tweets_data)
df.head()
# Out:
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-29803b82956f86aa'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-2980b594c656175d'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-298071d10786f6ab'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-298086f9a1d65f64'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-29801640eda8baa6'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-2980396d9c1dc9c2'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-2980a144d98a3ce5'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-2980e15ce666780a'
# Skipping unrecognised entry ID: 'promoted-tweet-1656398905490153474-29804c4ba05ffdf4'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-2980f123133dc700'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-29806152dad549b3'
# ...

# %%
df.shape
# Out:
# (1112, 10)

# %%
keywords = ['#chatgpt security', 'chatgpt cybersecurity','chatgpt hackers','#chatgpt cyberthreat']
limit = 200000

tweets_data = []

for keyword in keywords:
    search_query = f'{keyword} until:2023-01-10'
    tweets = list(sntwitter.TwitterSearchScraper(search_query).get_items())[:limit]
    
    
    for tweet in tweets:
        tweet_data = {
            'id':tweet.id,
            'date':tweet.date,
            'content':tweet.rawContent,
            'username':tweet.user.username,
            'verified':tweet.user.verified, 
            'location':tweet.user.location,
            'followerscount':tweet.user.followersCount,
            'language':tweet.lang,
            'mentions':tweet.mentionedUsers,
            'hashtags':tweet.hashtags
        }
        tweets_data.append(tweet_data)
df_1 = pd.DataFrame(tweets_data)
df_1.head()
# Out:
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-29812bf8c5d45cee'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-2981da0a40de6a52'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-2981fa0b169f6b55'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-29813f32c7cd467b'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-298168b215e13470'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-298107c5a45cf3ba'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-298125c1ed93b4af'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-2981ef44f5da7f98'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-29811d4bf997be11'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-29819bfd03099776'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-2981a933a1140caa'
# ...

# %%
df_1.shape
# Out:
# (2846, 10)

# %%
keywords = ['#chatgpt security', 'chatgpt cybersecurity','chatgpt hackers','#chatgpt cyberthreat']
limit = 200000

tweets_data = []

for keyword in keywords:
    search_query = f'{keyword} until:2023-01-30' #since:2023-02-01'
    tweets = list(sntwitter.TwitterSearchScraper(search_query).get_items())[:limit]
    
    
    for tweet in tweets:
        tweet_data = {
            'id':tweet.id,
            'date':tweet.date,
            'content':tweet.rawContent,
            'username':tweet.user.username,
            'verified':tweet.user.verified, 
            'location':tweet.user.location,
            'followerscount':tweet.user.followersCount,
            'language':tweet.lang,
            'mentions':tweet.mentionedUsers,
            'hashtags':tweet.hashtags
        }
        tweets_data.append(tweet_data)
df_2 = pd.DataFrame(tweets_data)
df_2.head()
# Out:
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-2989936e9f45e1c5'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-2989812af2c6a82b'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-29894a25da2c9098'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-2989e1d98bd8473e'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-2989d53014c36683'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-298997244aa1e976'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-2989f49c3b487b12'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-2989dca5673b9418'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-298955e9f162eb6d'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-29893c7627087a4e'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-298965c6821b75fa'
# ...

# %%
keywords = ['#chatgpt security', 'chatgpt cybersecurity','chatgpt hackers','#chatgpt cyberthreat']
limit = 200000

tweets_data = []

for keyword in keywords:
    search_query = f'{keyword} until:2023-03-30 since:2023-03-01'
    tweets = list(sntwitter.TwitterSearchScraper(search_query).get_items())[:limit]
    
    
    for tweet in tweets:
        tweet_data = {
            'id':tweet.id,
            'date':tweet.date,
            'content':tweet.rawContent,
            'username':tweet.user.username,
            'verified':tweet.user.verified, 
            'location':tweet.user.location,
            'followerscount':tweet.user.followersCount,
            'language':tweet.lang,
            'mentions':tweet.mentionedUsers,
            'hashtags':tweet.hashtags
        }
        tweets_data.append(tweet_data)
df_3 = pd.DataFrame(tweets_data)
df_3.head()
# Out:
# Skipping unrecognised entry ID: 'promoted-tweet-1656398905490153474-298c673e70a5f02d'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-298c652ea9511722'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-298cd670a1e1217c'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-298c57ae7b1322eb'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-298c4ce96e8f8654'
# Skipping unrecognised entry ID: 'promoted-tweet-1656398905490153474-298c48c4295cab5c'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-298c242f1a1ae561'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-298c00ee5ffd99ec'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-298cb0d820b54fba'
# Skipping unrecognised entry ID: 'promoted-tweet-1656398905490153474-298c335af81a7e26'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-298c248d89c75221'
# ...

# %%
keywords = ['#chatgpt security', 'chatgpt cybersecurity','chatgpt hackers','#chatgpt cyberthreat']
limit = 200000

tweets_data = []

for keyword in keywords:
    search_query = f'{keyword} until:2023-04-15 since:2023-04-01'
    tweets = list(sntwitter.TwitterSearchScraper(search_query).get_items())[:limit]
    
    
    for tweet in tweets:
        tweet_data = {
            'id':tweet.id,
            'date':tweet.date,
            'content':tweet.rawContent,
            'username':tweet.user.username,
            'verified':tweet.user.verified, 
            'location':tweet.user.location,
            'followerscount':tweet.user.followersCount,
            'language':tweet.lang,
            'mentions':tweet.mentionedUsers,
            'hashtags':tweet.hashtags
        }
        tweets_data.append(tweet_data)
df_4 = pd.DataFrame(tweets_data)
df_4.head()
# Out:
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-29935bb8e20151be'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-2993622e168a166e'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-2993a39d0859b07f'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-2993e4adc5dfc5ae'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-2993934196148a27'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-2993302fff56afe2'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-2993902da987bbda'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-29939447b8dc761f'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-29931349d387f421'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-2993dc597a61ce6c'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-2993e0175daf5aaf'
# ...

# %%
keywords = ['#chatgpt security', 'chatgpt cybersecurity','chatgpt hackers','#chatgpt cyberthreat']
limit = 200000

tweets_data = []

for keyword in keywords:
    search_query = f'{keyword} until:2023-04-30 since:2023-04-15'
    tweets = list(sntwitter.TwitterSearchScraper(search_query).get_items())[:limit]
    
    
    for tweet in tweets:
        tweet_data = {
            'id':tweet.id,
            'date':tweet.date,
            'content':tweet.rawContent,
            'username':tweet.user.username,
            'verified':tweet.user.verified, 
            'location':tweet.user.location,
            'followerscount':tweet.user.followersCount,
            'language':tweet.lang,
            'mentions':tweet.mentionedUsers,
            'hashtags':tweet.hashtags
        }
        tweets_data.append(tweet_data)
df_5 = pd.DataFrame(tweets_data)
df_5.head()
# Out:
# Skipping unrecognised entry ID: 'promoted-tweet-1656398905490153474-2995ea1d0424c6ab'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-29952021025cd752'
# Could not translate t.co card URL on tweet 1652337338104832002
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-2995764e9fb45059'
# Skipping unrecognised entry ID: 'promoted-tweet-1655910461840269312-299531d8fa9e083f'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-299571974888b702'
# Skipping unrecognised entry ID: 'promoted-tweet-1655910461840269312-299529eb667d4264'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-299553f71d9f80d2'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-299596a308cd0239'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-2995883585025e4d'
# Skipping unrecognised entry ID: 'promoted-tweet-1656398905490153474-29956b69e4fb3fae'
# ...

# %%
keywords = ['#chatgpt security', '#chatgpt cybersecurity','#chatgpt hackers','#chatgpt cyberthreat']
limit = 200000

tweets_data = []

for keyword in keywords:
    search_query = f'{keyword} until:2023-05-15 since:2023-05-01'
    tweets = list(sntwitter.TwitterSearchScraper(search_query).get_items())[:limit]
    
    
    for tweet in tweets:
        tweet_data = {
            'id':tweet.id,
            'date':tweet.date,
            'content':tweet.rawContent,
            'username':tweet.user.username,
            'verified':tweet.user.verified, 
            'location':tweet.user.location,
            'followerscount':tweet.user.followersCount,
            'language':tweet.lang,
            'mentions':tweet.mentionedUsers,
            'hashtags':tweet.hashtags
        }
        tweets_data.append(tweet_data)
df_6 = pd.DataFrame(tweets_data)
df_6.head()
# Out:
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-29973ce0d7ceadf8'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-29974f1a2371b50f'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-2997e4817a3243b7'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-2997209ffe492765'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-2997e5093db72349'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-29976acdebbad782'
# Skipping unrecognised entry ID: 'promoted-tweet-1656398905490153474-2997cb7eb5ec2fe7'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-2997d41064bfe4d5'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-29971e3c5d29279b'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-299787d05f32a90d'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-29973d5c59171dec'
# ...

# %%
keywords = ['#chatgpt security', '#chatgpt cybersecurity','#chatgpt hackers','#chatgpt cyberthreat']
limit = 200000

tweets_data = []

for keyword in keywords:
    search_query = f'{keyword} until:2023-05-30 since:2023-05-15'
    tweets = list(sntwitter.TwitterSearchScraper(search_query).get_items())[:limit]
    
    
    for tweet in tweets:
        tweet_data = {
            'id':tweet.id,
            'date':tweet.date,
            'content':tweet.rawContent,
            'username':tweet.user.username,
            'verified':tweet.user.verified, 
            'location':tweet.user.location,
            'followerscount':tweet.user.followersCount,
            'language':tweet.lang,
            'mentions':tweet.mentionedUsers,
            'hashtags':tweet.hashtags
        }
        tweets_data.append(tweet_data)
df_7 = pd.DataFrame(tweets_data)
df_7.head()
# Out:
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-2998af9fbfc96b41'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-29983c510267ea29'
# Skipping unrecognised entry ID: 'promoted-tweet-1655910461840269312-299897fd86c2c48e'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-29984ab12c6db97d'
# Skipping unrecognised entry ID: 'promoted-tweet-1656117099260178437-299859b6aa97f219'
# Skipping unrecognised entry ID: 'promoted-tweet-1657391423103041536-29985104056ec8ec'
# Skipping unrecognised entry ID: 'promoted-tweet-1488462860183392258-2998f252f9bef26d'
# Skipping unrecognised entry ID: 'promoted-tweet-1661660141522145290-2998a6c1dffd5eab'
# Skipping unrecognised entry ID: 'promoted-tweet-1656398905490153474-2998d2cb2aca560c'
# Could not translate t.co card URL on tweet 1661272785199693824
# Could not translate t.co card URL on tweet 1661262729016147975
# ...

# %%
df_final = pd.concat([df, df_1, df_2, df_3, df_4, df_5, df_6, df_7], ignore_index=False)
df_final.shape
# Out:
# (27045, 10)

# %%
df_final.head()
# Out:
#                     id                      date
# 0  1608523372815683588 2022-12-29 18:00:31+00:00  \
# 1  1608489602154913799 2022-12-29 15:46:20+00:00
# 2  1608471387118895104 2022-12-29 14:33:57+00:00
# 3  1608451577714728960 2022-12-29 13:15:14+00:00
# 4  1608353993629073410 2022-12-29 06:47:28+00:00
#
#                                              content        username
# 0  Code-generating #AI can introduce #security #v...    VeilleCyber3  \
# 1  A #DevOps #Security Tutorial for #Digital #Bus...       IoTdevOps
# 2  https://t.co/5I2P3sLmCF #vpn #privacy #chatgpt...  nezirzahirovic
# 3  Advanced prompt engineering also needs some ki...          halllo
# 4  #ChatGPT is a big #Deal and here’s why…\n\n-- ...        MrMarchi
#
#    verified              location  followerscount language
# 0     False                 Paris            3193       en  \
# 1     False  Domain Name For Sale            1036       es
# 2     False                                  1184      qme
# ...

# %%
tweet_eng = df_final[df_final['language']=='en']
tweet_eng.to_csv('English_tweet_new.csv', index=False)

# %%
df_eng_1= pd.read_csv('English_tweet_new.csv')
df_eng_2 = pd.read_csv('English_tweets.csv')

# %%
df = pd.concat([df_eng_1, df_eng_2], ignore_index=False)
df.reset_index(drop=True)
# Out:
#                         id                       date
# 0      1608523372815683588  2022-12-29 18:00:31+00:00  \
# 1      1608451577714728960  2022-12-29 13:15:14+00:00
# 2      1608353993629073410  2022-12-29 06:47:28+00:00
# 3      1608353916726427650  2022-12-29 06:47:10+00:00
# 4      1608194440408989696  2022-12-28 20:13:28+00:00
# ...                    ...                        ...
# 67112  1598336577394163712  2022-12-01 15:21:50+00:00
# 67113  1598305466777571330  2022-12-01 13:18:13+00:00
# 67114  1598296764184154112  2022-12-01 12:43:38+00:00
# 67115  1598293329489584130  2022-12-01 12:29:59+00:00
# 67116  1598206815019438081  2022-12-01 06:46:12+00:00
#
#                                                  content        username
# 0      Code-generating #AI can introduce #security #v...    VeilleCyber3  \
# 1      Advanced prompt engineering also needs some ki...          halllo
# 2      #ChatGPT is a big #Deal and here’s why…\n\n-- ...        MrMarchi
# ...

# %% [markdown]
# ## Data Manipulation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 67117 entries, 0 to 43835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              67117 non-null  int64
#  1   date            67117 non-null  object
#  2   content         67117 non-null  object
#  3   username        67117 non-null  object
#  4   verified        23281 non-null  object
#  5   location        16579 non-null  object
#  6   followerscount  23281 non-null  float64
#  7   language        67117 non-null  object
#  8   mentions        13570 non-null  object
#  9   hashtags        52950 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 5.6+ MB

# %%
#Split the datetime columns into two separate columns for easy processing
df['date']=pd.to_datetime(df['date'])
df['Datecreated'] = df['date'].dt.date
df['Month'] = df['date'].dt.month
df['Year'] = df['date'].dt.year
df['Day'] = df['date'].dt.day

# %%
df.head()
# Out:
#                     id                      date
# 0  1608523372815683588 2022-12-29 18:00:31+00:00  \
# 1  1608451577714728960 2022-12-29 13:15:14+00:00
# 2  1608353993629073410 2022-12-29 06:47:28+00:00
# 3  1608353916726427650 2022-12-29 06:47:10+00:00
# 4  1608194440408989696 2022-12-28 20:13:28+00:00
#
#                                              content        username verified
# 0  Code-generating #AI can introduce #security #v...    VeilleCyber3    False  \
# 1  Advanced prompt engineering also needs some ki...          halllo    False
# 2  #ChatGPT is a big #Deal and here’s why…\n\n-- ...        MrMarchi    False
# 3  #ChatGPT is a big #Deal and here’s why…\n\n-- ...       MrSkanner    False
# 4  I’ve been down the chat GPT rabbit hole.. and ...  angelesgomez__    False
#
#              location  followerscount language
# 0               Paris          3193.0       en  \
# 1  Karlsruhe, Germany           677.0       en
# 2       United States          5815.0       en
# ...

# %%
# check for missing dates in the data
df['date'].isna().sum()
# Out:
# 0

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from tqdm import tqdm
import re
import sys

#download these packages in nltk if you dont have it already 
nltk.download(["names","stopwords","twitter_samples", "averaged_perceptron_tagger","vader_lexicon","punkt"])


#create data for stopwords like a, the and I etc 
stopwords = nltk.corpus.stopwords.words("english")
Clean_tweet=[]
def clean(df):
    punc = '''!(-[{;:'"\/|<>,.?@#$%^&*_~`}])'''
    i =0
    for row in tqdm(df['content'], desc="cleaning", total=len(df)):
        row = re.sub(r'@[A-Za-z0-9]+', '', row) # remove @menstions
        row = re.sub(r'#', '', row) # remove #
        row = re.sub(r'\n', '',row) 
        row = re.sub(r'RT[\s]+', '', row) # remove RT
        row = re.sub(r'https?:\/\/\S+', '', row)
        emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags=re.UNICODE)
        row= emoji_pattern.sub(r'', row) # no emoji

        for word in row:
                for char in word:
                    if char in punc:
                        row = row.replace(char, " ")
            
        text_tokens = word_tokenize(row.lower())
        tokens_without_sw = [word for word in text_tokens if word not in stopwords]
        row = (" ").join(tokens_without_sw)
        

          
        Clean_tweet.append(row)
        i+= 1
    Clean_tweet_df =pd.DataFrame(Clean_tweet, columns= ["Clean_tweet"])
    df=pd.concat([df.reset_index(drop=True),Clean_tweet_df],axis=1)
    return df
# Out:
# [nltk_data] Downloading package names to /home/daniel/nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/daniel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /home/daniel/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/daniel/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/daniel/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to /home/daniel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df_without_stopwords = clean(df)
# Out:
# cleaning: 100%|█████████████████████████| 67117/67117 [00:10<00:00, 6337.52it/s]

# %%
df_without_stopwords['Clean_tweet'][0:20]
# Out:
# 0     code generating ai introduce security vulnerab...
# 1     advanced prompt engineering also needs kind se...
# 2     chatgpt big deal ’ why… digital security ai ai...
# 3     chatgpt big deal ’ why… digital security ai ai...
# 4     ’ chat gpt rabbit hole ’ fucking scared ’ maki...
# 5     security attack chatgpt artificialintelligence...
# 6     code generating ai introduce security vulnerab...
# 7     published github action poc openai checks modi...
# 8     used chatgpt generate first drafts compliance ...
# 9     ’ played around chatgpt chatgpt3 truly impress...
# 10    rising inception dockers containers kubernetes...
# 11    financial literacykey wealth securityinvest kn...
# 12    starting get worried job security rest assured...
# 13    many talks security cons 2023 include least on...
# 14    new post connor mccrory amazon security lake w...
# 15    digital agents digital visions britaingetsingi...
# 16    bitcoin features bitcoin cryptocurrencies incl...
# ...

# %%
punc = '''!(-[{;:'"\/|<>,.?@#$%^&*_~`}])'''

df_without_stopwords['Clean_tweet'] = df_without_stopwords['Clean_tweet'].apply(lambda x: re.sub(punc, '', x))

#Replace 'chat gpt' with 'chatgpt'

# %% [markdown]
# We now have a cleaner text for further processing

# %%
# Tokenization
# Apply the split function on the clean tweet to get the tokenized tweet and append as a new table


df_without_stopwords['Tweet_tokenized'] = df_without_stopwords['Clean_tweet'].apply(lambda x: re.split('\W+', x))

# %%
df_without_stopwords['Tweet_tokenized']
# Out:
# 0        [code, generating, ai, introduce, security, vu...
# 1        [advanced, prompt, engineering, also, needs, k...
# 2        [chatgpt, big, deal, why, digital, security, a...
# 3        [chatgpt, big, deal, why, digital, security, a...
# 4        [, chat, gpt, rabbit, hole, fucking, scared, m...
#                                ...
# 67112    [alway, technology, new, technology, used, goo...
# 67113    [glad, see, train, chatgpt, hacker, news, comm...
# 67114    [seeing, lots, examples, using, chatgpt, show,...
# 67115    [kidding, asked, chatgpt, write, rap, song, ha...
# 67116    [cat, hacker, openai, chatgpt, optimizing, lan...
# Name: Tweet_tokenized, Length: 67117, dtype: object

# %% [markdown]
# ## Lemmatization

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /home/daniel/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/daniel/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk import pos_tag
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer


#define a function to map POS tags from treebank tag into wordnet tags
word_net_lem = WordNetLemmatizer()
def get_wordnet(pos):
    if pos.startswith('N'): 
        return wordnet.NOUN
    elif pos.startswith('V'):
        return wordnet.VERB
    elif pos.startswith('J'):
        return wordnet.ADJ
    elif pos.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN     #default to noun if no match

    
# Define a function to tag and lemmatize a text string    
def lemmatizer(text):
    pos_tags = pos_tag(text)
    text = [word_net_lem.lemmatize(word, pos = get_wordnet(pos)) for word, pos in pos_tags]
    return text

# apply the function on the tokenized tweet to get the lemmatized tweets
df_without_stopwords['Tweet_lemmatized'] = df_without_stopwords['Tweet_tokenized'].apply(lambda x: lemmatizer(x))

# %%
df_without_stopwords['Tweet_lemmatized'][0:10]
# Out:
# 0    [code, generate, ai, introduce, security, vuln...
# 1    [advanced, prompt, engineering, also, need, ki...
# 2    [chatgpt, big, deal, why, digital, security, a...
# 3    [chatgpt, big, deal, why, digital, security, a...
# 4    [, chat, gpt, rabbit, hole, fucking, scar, mak...
# 5    [security, attack, chatgpt, artificialintellig...
# 6    [code, generate, ai, introduce, security, vuln...
# 7    [publish, github, action, poc, openai, check, ...
# 8    [use, chatgpt, generate, first, draft, complia...
# 9    [, play, around, chatgpt, chatgpt3, truly, imp...
# Name: Tweet_lemmatized, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'date', 'content', 'username', 'verified', 'location',
#        'followerscount', 'language', 'mentions', 'hashtags', 'Datecreated',
#        'Month', 'Year', 'Day', 'Clean_tweet', 'Tweet_tokenized',
#        'Tweet_lemmatized'],
#       dtype='object')

# %%
# Final Tokens

df_without_stopwords['Tokens'] = df_without_stopwords['Tweet_lemmatized'].apply(lambda x: ' '.join(x))

df_without_stopwords['Tokens'][13]
# Out:
# 'many talk security con 2023 include least one slide chatgpt output care guess cybersecurity openai'

# %%
# Remove Unneccesary columns and save the file
df_without_stopwords.to_csv('Final_tweet_LDA.csv', index=False)

# %%
# !pip install wordcloud
# !pip install numpy matplotlib pillow
import numpy as np
import PIL.Image
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 460.4/460.4 kB 44.9 MB/s eta 0:00:00
# ...

# %%
from wordcloud import WordCloud


#prepare the long_string for wordcloud
long_string_cloud = ' '.join(list(df['Tokens']))

# %%
import matplotlib.pyplot as plt

# %%
def wordcloud_generate(string):
#load the mask image
    #mask = np.array(PIL.Image.open('chatgpt3.png'))

    #define the wordcloud object
    wordcloud = WordCloud(scale =1,
                          mask = None, 
                          background_color='black',
                          max_words=100,
                          contour_width=1,
                          contour_color='#74aa9c',
                         colormap='gist_earth',
                         stopwords=['chatgpt'])

    #generate the wordcloud
    wc = wordcloud.generate(string)

    #display the wordcloud
    fig = plt.figure(figsize=(12,8))
    plt.imshow(wc, interpolation = 'bilinear')
    plt.axis("off")
    plt.show()
    plt.savefig('wordcloud.png', dpi=300)
wordcloud_generate(long_string_cloud)
